# %%
import numpy as np

a=np.random.rand(2,3)
a

# %%
points = np.array([
    [0, 0]
])
if len(points)<4:
    points = np.vstack((points[:-1],points[-1:],points[-1:],points[-1:]))
points

# %%
a = [1,2,3]
del a[0]
a

# %%
import torch
curr_pos = torch.rand(10,3)
prev_pos = torch.rand(10,3)
dist = torch.norm(curr_pos - prev_pos, dim=-1)
for i, d in enumerate(dist):
    print(f"dist {i}: {d}")
    history[i].append(d)
    if len(history[i]) > 10:
        history[i].pop(0)
dist = torch.stack([torch.mean(torch.tensor(d)) for d in history])
print(f"dist: {dist}")
same_pos = torch.logical_and(dist < 0.7, dist > 0.0001)
same_pos_count = torch.zeros(10, dtype=torch.int32)
same_pos_count[same_pos] += 1
same_pos_count[~same_pos] = 0
print(f"same_pos: {same_pos}, dist: {dist}, same_pos_count: {same_pos_count}")

# %%
history = [[] for _ in range(10)]

# %%
same_pos

# %%
history
