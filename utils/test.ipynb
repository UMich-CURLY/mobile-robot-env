# %%
import numpy as np

a=np.random.rand(2,3)
a
# Out:
# array([[0.33121294, 0.77346548, 0.57083386],
#        [0.63576032, 0.39374153, 0.35899884]])

# %%
points = np.array([
    [0, 0]
])
if len(points)<4:
    points = np.vstack((points[:-1],points[-1:],points[-1:],points[-1:]))
points
# Out:
# array([[0, 0],
#        [0, 0],
#        [0, 0]])

# %%
a = [1,2,3]
del a[0]
a
# Out:
# [2, 3]

# %%
import torch
curr_pos = torch.rand(10,3)
prev_pos = torch.rand(10,3)
dist = torch.norm(curr_pos - prev_pos, dim=-1)
for i, d in enumerate(dist):
    print(f"dist {i}: {d}")
    history[i].append(d)
    if len(history[i]) > 10:
        history[i].pop(0)
dist = torch.stack([torch.mean(torch.tensor(d)) for d in history])
print(f"dist: {dist}")
# Out:
# dist 0: 0.6384381055831909
# dist 1: 0.9544704556465149
# dist 2: 0.5562437772750854
# dist 3: 0.812152624130249
# dist 4: 0.5092487335205078
# dist 5: 0.6838713884353638
# dist 6: 0.3888167440891266
# dist 7: 0.24899525940418243
# dist 8: 0.1611868292093277
# dist 9: 0.1592164933681488
# dist: tensor([0.5113, 0.5113, 0.5113, 0.5113, 0.5113, 0.5113, 0.5113, 0.5113, 0.5113,
#         0.5113])

# %%
history = [[] for _ in range(10)]

# %%
history
# Out:
# [[tensor(0.6384),
#   tensor(0.9545),
#   tensor(0.5562),
#   tensor(0.8122),
#   tensor(0.5092),
#   tensor(0.6839),
#   tensor(0.3888),
#   tensor(0.2490),
#   tensor(0.1612),
#   tensor(0.1592)],
#  [tensor(0.6384),
#   tensor(0.9545),
#   tensor(0.5562),
#   tensor(0.8122),
#   tensor(0.5092),
#   tensor(0.6839),
#   tensor(0.3888),
#   tensor(0.2490),
#   tensor(0.1612),
#   tensor(0.1592)],
#  [tensor(0.6384),
#   tensor(0.9545),
#   tensor(0.5562),
#   tensor(0.8122),
#   tensor(0.5092),
#   tensor(0.6839),
#   tensor(0.3888),
#   tensor(0.2490),
#   tensor(0.1612),
#   tensor(0.1592)],
#  [tensor(0.6384),
#   tensor(0.9545),
#   tensor(0.5562),
#   tensor(0.8122),
#   tensor(0.5092),
#   tensor(0.6839),
#   tensor(0.3888),
#   tensor(0.2490),
#   tensor(0.1612),
#   tensor(0.1592)],
#  [tensor(0.6384),
#   tensor(0.9545),
#   tensor(0.5562),
#   tensor(0.8122),
#   tensor(0.5092),
#   tensor(0.6839),
#   tensor(0.3888),
#   tensor(0.2490),
#   tensor(0.1612),
#   tensor(0.1592)],
#  [tensor(0.6384),
#   tensor(0.9545),
#   tensor(0.5562),
#   tensor(0.8122),
#   tensor(0.5092),
#   tensor(0.6839),
#   tensor(0.3888),
#   tensor(0.2490),
#   tensor(0.1612),
#   tensor(0.1592)],
#  [tensor(0.6384),
#   tensor(0.9545),
#   tensor(0.5562),
#   tensor(0.8122),
#   tensor(0.5092),
#   tensor(0.6839),
#   tensor(0.3888),
#   tensor(0.2490),
#   tensor(0.1612),
#   tensor(0.1592)],
#  [tensor(0.6384),
#   tensor(0.9545),
#   tensor(0.5562),
#   tensor(0.8122),
#   tensor(0.5092),
#   tensor(0.6839),
#   tensor(0.3888),
#   tensor(0.2490),
#   tensor(0.1612),
#   tensor(0.1592)],
#  [tensor(0.6384),
#   tensor(0.9545),
#   tensor(0.5562),
#   tensor(0.8122),
#   tensor(0.5092),
#   tensor(0.6839),
#   tensor(0.3888),
#   tensor(0.2490),
#   tensor(0.1612),
#   tensor(0.1592)],
#  [tensor(0.6384),
#   tensor(0.9545),
#   tensor(0.5562),
#   tensor(0.8122),
#   tensor(0.5092),
#   tensor(0.6839),
#   tensor(0.3888),
#   tensor(0.2490),
#   tensor(0.1612),
#   tensor(0.1592)]]
