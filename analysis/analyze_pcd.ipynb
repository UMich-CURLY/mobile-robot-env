# %%
from utils.explored_map_utils import build_full_scene_pcd
import numpy as np
import open3d as o3d
# %cd analysis/
rgb = np.load('rgb.npy')
depth = np.load('depth.npy')
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.
# /workspace/Projects/SG-VLN/analysis
# /root/conda/envs/vln/lib/python3.10/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
pcd = build_full_scene_pcd(depth,rgb,60)
#o3d.io.write_point_cloud('points.ply',pcd)
# Out:
# True

# %%
import pickle

data = {'rgb':rgb,'depth':depth}

pickle.dump(data,open('frame','+w'))

with open("frame", "wb") as output_file:
    pickle.dump(data,output_file)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[70], line 5
#       1 import pickle
#       3 data = {'rgb':rgb,'depth':depth}
# ----> 5 pickle.dump(data,open('frame','+w'))
#
# TypeError: write() argument must be str, not bytes

# %%
width = 640
hfov = 55 #618.95
fx = (width / 2.) / np.tan(np.deg2rad(hfov / 2.))
print(fx)
# Out:
# 614.7142806307731

# %%
rgb = np.load('rgb.npy')
depth = np.load('depth.npy')

# %%
pcd = build_full_scene_pcd(depth,rgb,55)
colors = np.asarray(pcd.colors)
pcd = np.asarray(pcd.points)

mask = (pcd[:,1]>0)#*(pcd[:,1]>-1000)
pcd = pcd[mask]
colors = colors[mask]

x = pcd[:,0]
y = pcd[:,2]
z = pcd[:,1]
import matplotlib.pyplot as plt

plt.scatter(x,y,c=colors,s=0.01)
plt.gca().set_aspect('equal')

# %%
colors.shape
# Out:
# (299267, 3)

# %%
plt.imshow(rgb)

# %%
colors.shape
# Out:
# (148921, 3)

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 3
#       1 import matplotlib.pyplot as plt
# ----> 3 plt.scatter(x,y,c=colors)
#
# NameError: name 'x' is not defined
