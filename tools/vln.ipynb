# %%
# %reload_ext autoreload
# %autoreload 2
import sys
sys.path.append("..")
import numpy as np
from utils.instruction_generator import InstructionGenerator

instruction_generator = InstructionGenerator("../episodes", "/home/junzhe_lighthouse/lighthouse/scratch/isaac_scenes_v1/episode_data")

# %%
# result = instruction_generator.generate_instruction("nv_apartment", 8)
result = instruction_generator.generate_instruction("nv_parkmorning", 1)

# %%
import os

i = 0
instruction_generator.vlm_based_generation(result[i]["episode"], result[i]["aligned_instructions"])
