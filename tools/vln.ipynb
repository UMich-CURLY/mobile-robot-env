# %%
# %reload_ext autoreload
# %autoreload 2
import sys
sys.path.append("..")
import numpy as np
from utils.instruction_generator import InstructionGenerator

instruction_generator = InstructionGenerator("../episodes", "/home/junzhe_lighthouse/lighthouse/scratch/isaac_scenes_v1/episode_data")

# %%
instruction_generator.generate_instruction("nv_apartment", 4)
# Out:
# ...
# Generating instruction for episode 0
# Path image generated and saved to /home/junzhe_lighthouse/lighthouse/scratch/isaac_scenes_v1/episode_data/nv_apartment_0/path_reference_path.png
# Path image generated and saved to /home/junzhe_lighthouse/lighthouse/scratch/isaac_scenes_v1/episode_data/nv_apartment_0/path_simplified_path.png
# Full instruction: Slightly turn left, then move forward 13.41 m. You will arrive at the hydrant.
# Aligned instructions: [(88, 'Slightly turn left, then move forward 13.41 m.'), (91, 'You will arrive at the hydrant.')]
# Video generated and saved to /home/junzhe_lighthouse/lighthouse/scratch/isaac_scenes_v1/episode_data/nv_apartment_0/video_instruction.mp4
# ...
# Generating instruction for episode 1
# Path image generated and saved to /home/junzhe_lighthouse/lighthouse/scratch/isaac_scenes_v1/episode_data/nv_apartment_1/path_reference_path.png
# ...

# %%
import numpy as np
from scipy.spatial.transform import Rotation as R
R.from_euler('Z', 1).as_euler('ZYX')[0]
# Out:
# 1.0

# %%
wp = instruction_generator._merge_wp([1,0,np.deg2rad(45)], [0,0,np.deg2rad(45)])
print(f"dx={wp[0]:.2f}, dy={wp[1]:.2f}, yaw_diff={np.rad2deg(wp[2]):.2f}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 wp = instruction_generator._merge_wp([1,0,np.deg2rad(45)], [0,0,np.deg2rad(45)])
#       2 print(f"dx={wp[0]:.2f}, dy={wp[1]:.2f}, yaw_diff={np.rad2deg(wp[2]):.2f}")
#
# NameError: name 'instruction_generator' is not defined

# %%
from IPython.display import Video
Video('/home/junzhe_lighthouse/lighthouse/scratch/isaac_scenes_v1/episode_data/nv_apartment_2/video_instruction.mp4')
# Out:
# <video src="/home/junzhe_lighthouse/lighthouse/scratch/isaac_scenes_v1/episode_data/nv_apartment_2/video_instruction.mp4" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>
